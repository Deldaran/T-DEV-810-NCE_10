# %% [markdown]
# # MNIST dataset
#
# ## Download
# We need to download it from [https://www.kaggle.com/datasets/hojjatk/mnist-dataset](https://www.kaggle.com/datasets/hojjatk/mnist-dataset).

# %%
import os

# Define the expected directories
expected_dirs = [
    't10k-images-idx3-ubyte', 
    't10k-labels-idx1-ubyte', 
    'train-images-idx3-ubyte', 
    'train-labels-idx1-ubyte'
]

# Check if the dataset structure is already present
all_dirs_exist = all(os.path.isdir(dir) for dir in expected_dirs)


# Define the expected files for each directory
expected_files = {
    't10k-images-idx3-ubyte': ['t10k-images-idx3-ubyte'],
    't10k-labels-idx1-ubyte': ['t10k-labels-idx1-ubyte'],
    'train-images-idx3-ubyte': ['train-images-idx3-ubyte'],
    'train-labels-idx1-ubyte': ['train-labels-idx1-ubyte'],
}

# Check if all expected files are present in their respective directories
all_files_exist = all(
    os.path.isfile(os.path.join(dir, file)) 
    for dir, files in expected_files.items() 
    for file in files
)

if all_dirs_exist and all_files_exist:
    print("✅ Dataset is already in place with the correct structure.")
else:
    print("❌ Dataset structure incomplete. Download it from https://www.kaggle.com/datasets/hojjatk/mnist-dataset")
# Out:
# ✅ Dataset is already in place with the correct structure.
